# %% [markdown]
# <a href="https://colab.research.google.com/github/niran-j2005/assesment/blob/main/Assesment_Niranjan_S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#1
arr=np.array([10,20,30,40,50])
arr
# Out:
# array([10, 20, 30, 40, 50])

# %%
#2
arr=np.array([5,10,15,20,25])
arr
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
#3
arr=np.array([12,15,18,20,25,30])
arr
print("the mean is ",np.mean(arr))
print("the meadian is",np.median(arr))
print("the minimum is",np.min(arr))
print("the maximum is",np.max(arr))
print("the standard deviation is",np.std(arr))
# Out:
# the mean is  20.0
# the meadian is 19.0
# the minimum is 12
# the maximum is 30
# the standard deviation is 6.027713773341708

# %%
#4
arr=np.array([10,25,30,45,50,65,70])
print("the numbers that are greater than 40 is",arr[arr>40])
# Out:
# the numbers that are greater than 40 is [45 50 65 70]

# %%
#5
data=[{"name":"anu","age":21,"score":85},
     {"name":"rahul","age":22,"score":72},
      {"name":"meera","age":20,"score":91},
      {"name":"arun","age":23,"score":68}]
pd=pd.DataFrame(data)
pd
# Out:
#     name  age  score
# 0    anu   21     85
# 1  rahul   22     72
# 2  meera   20     91
# 3   arun   23     68

# %%
#6
pd[["name","score"]]
pd[pd["name"]=="meera"]
# Out:
#     name  age  score
# 2  meera   20     91

# %%
#7
pd[pd["score"]>75]
# Out:
#     name  age  score
# 0    anu   21     85
# 2  meera   20     91

# %%
#8
pd.columns#2
pd.dtypes#3
pd.shape#1
pd.describe()#4
# Out:
#              age      score
# count   4.000000   4.000000
# mean   21.500000  79.000000
# std     1.290994  10.801234
# min    20.000000  68.000000
# 25%    20.750000  71.000000
# 50%    21.500000  78.500000
# 75%    22.250000  86.500000
# max    23.000000  91.000000

# %%
#9
pd.sort_values(by="score",ascending=False)
# Out:
#     name  age  score
# 2  meera   20     91
# 0    anu   21     85
# 1  rahul   22     72
# 3   arun   23     68

# %%
df = pd.DataFrame({
'Name': ['A', 'B', 'C', 'D'],
'Age': [21, np.nan, 23, 22],
'Score': [80, 75, np.nan, 90]
})
df.isnull()#1
df["Age"] = df["Age"].fillna(df["Age"].mean())#2
df["Score"] = df["Score"].fillna(df["Score"].mean())#3
df
# Out:
#   Name   Age      Score
# 0    A  21.0  80.000000
# 1    B  22.0  75.000000
# 2    C  23.0  81.666667
# 3    D  22.0  90.000000

# %%
#11
filepath="/content/student_performance.csv"
df=pd.read_csv(filepath)
df
# Out:
#    Student_ID            Name  Gender        Department   Age  Attendance  \
# 0     STU1001     Rahul Varma    Male  Computer Science  25.0        74.7
# 1     STU1002    Kiran Pillai    Male  Computer Science  24.0        75.5
# 2     STU1003  Fathima Joseph  Female       Electronics  21.0        60.5
# 3     STU1004    Rahul Sharma  Female      Data Science  25.0        80.4
# 4     STU1005       Asha Nair  Female      Data Science  22.0        71.4
# ..        ...             ...     ...               ...   ...         ...
# 75    STU1076     Priya Kumar  Female  Computer Science  24.0        99.3
# 76    STU1077      Amal Kumar    Male      Data Science   NaN        93.8
# 77    STU1078  Fathima Sharma    Male  Computer Science  19.0        86.4
# 78    STU1079    Meera Thomas    Male       Electronics  23.0        99.4
# 79    STU1080      Diya Varma    Male       Electronics  19.0        86.4
#
#     Python_Score  SQL_Score  Pandas_Score  NumPy_Score  Final_Score
# ...

# %%
#11
df.head()#1
df.tail()#2
df.shape#3
df.columns#4
df.dtypes#5
df.describe()#5
# Out:
#              Age  Attendance  Python_Score   SQL_Score  Pandas_Score  \
# count  77.000000   77.000000     78.000000   80.000000     78.000000
# mean   22.012987   81.672727     72.821795   70.445000     70.365385
# std     2.155126   10.054204     16.722103   14.630417     15.814294
# min    19.000000   56.300000     39.500000   38.300000     25.000000
# 25%    20.000000   75.500000     64.525000   60.650000     61.800000
# 50%    22.000000   81.100000     72.000000   69.300000     70.000000
# 75%    24.000000   86.400000     86.525000   81.150000     82.575000
# max    25.000000  100.000000    100.000000  100.000000    100.000000
#
#        NumPy_Score  Final_Score
# count    78.000000    78.000000
# mean     68.574359    70.696154
# std      16.417242    14.053871
# min      25.000000    40.600000
# 25%      57.175000    60.450000
# 50%      70.700000    70.950000
# 75%      80.650000    82.275000
# max     100.000000    97.000000

# %%
#12
df[df["Final_Score"]>75]#1
df[df["Attendance"]<75]#2
df[(df["Department"] == "Data Science") & (df["Final_Score"] > 80)]#3
df.sort_values(by="Final_Score",ascending=False)#4
# Out:
#    Student_ID           Name    Gender        Department   Age  Attendance  \
# 48    STU1049    Asha Sharma      Male      Data Science  22.0        91.3
# 61    STU1062   Kiran Pillai    Female  Computer Science  19.0        83.8
# 40    STU1041    Amal Pillai    Female  Computer Science  25.0        97.7
# 55    STU1056    Vivek Varma      Male      Data Science  22.0        81.0
# 57    STU1058    Diya Thomas    Female  Computer Science  23.0        83.5
# ..        ...            ...       ...               ...   ...         ...
# 34    STU1035   Rahul Pillai    Female      Data Science  22.0        82.5
# 76    STU1077     Amal Kumar      Male      Data Science   NaN        93.8
# 26    STU1027  Aditya Pillai    Female  Computer Science  25.0        79.6
# 42    STU1043    Sneha Varma   female       Data Science  19.0        74.4
# 53    STU1054    Maya Sharma      Male      Data Science  19.0        82.5
#
#     Python_Score  SQL_Score  Pandas_Score  NumPy_Score  Final_Score
# ...

# %%
#13
df["Average_Technical_Score"]=df[["Python_Score","SQL_Score","Pandas_Score","NumPy_Score"]].mean(axis=1)
df
# Out:
#    Student_ID            Name  Gender        Department   Age  Attendance  \
# 0     STU1001     Rahul Varma    Male  Computer Science  25.0        74.7
# 1     STU1002    Kiran Pillai    Male  Computer Science  24.0        75.5
# 2     STU1003  Fathima Joseph  Female       Electronics  21.0        60.5
# 3     STU1004    Rahul Sharma  Female      Data Science  25.0        80.4
# 4     STU1005       Asha Nair  Female      Data Science  22.0        71.4
# ..        ...             ...     ...               ...   ...         ...
# 75    STU1076     Priya Kumar  Female  Computer Science  24.0        99.3
# 76    STU1077      Amal Kumar    Male      Data Science   NaN        93.8
# 77    STU1078  Fathima Sharma    Male  Computer Science  19.0        86.4
# 78    STU1079    Meera Thomas    Male       Electronics  23.0        99.4
# 79    STU1080      Diya Varma    Male       Electronics  19.0        86.4
#
#     Python_Score  SQL_Score  Pandas_Score  NumPy_Score  Final_Score  \
# ...

# %%
#15
df["Name"].count()
df["Final_Score"].mean()
df["Final_Score"].max()
df["Final_Score"].min()
sorted_df = df.sort_values(by="Final_Score", ascending=False)
sorted_df
# Out:
#    Student_ID           Name    Gender        Department   Age  Attendance  \
# 48    STU1049    Asha Sharma      Male      Data Science  22.0        91.3
# 61    STU1062   Kiran Pillai    Female  Computer Science  19.0        83.8
# 40    STU1041    Amal Pillai    Female  Computer Science  25.0        97.7
# 55    STU1056    Vivek Varma      Male      Data Science  22.0        81.0
# 57    STU1058    Diya Thomas    Female  Computer Science  23.0        83.5
# ..        ...            ...       ...               ...   ...         ...
# 34    STU1035   Rahul Pillai    Female      Data Science  22.0        82.5
# 76    STU1077     Amal Kumar      Male      Data Science   NaN        93.8
# 26    STU1027  Aditya Pillai    Female  Computer Science  25.0        79.6
# 42    STU1043    Sneha Varma   female       Data Science  19.0        74.4
# 53    STU1054    Maya Sharma      Male      Data Science  19.0        82.5
#
# ...

# %%
#16
score_array=df["Final_score"] to_NumPy
